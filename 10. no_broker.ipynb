# %%
import pandas as pd
import requests
from bs4 import BeautifulSoup
import numpy as np
import re

# %%
url="https://www.nobroker.in/property/sale/mumbai/Worli%20Sea%20Face?searchParam=W3sibGF0IjoxOS4wMDkxNDMyLCJsb24iOjcyLjgxNTcyODMsInBsYWNlSWQiOiJDaElKdjJ6akhwak81enNSRGYwYVB0MzVfdXciLCJwbGFjZU5hbWUiOiJXb3JsaSBTZWEgRmFjZSJ9XQ==&radius=2.0"

# %%
output=requests.get(url)

# %%
output
# Out:
# <Response [200]>

# %%
soup=BeautifulSoup(output.content,"html.parser")

# %%
print(soup)
# Out:
# <!DOCTYPE html>
# <html lang="en"><head>
# <meta content="794951570520699" property="fb:pages"/>
# <link href="https://www.nobroker.in" rel="canonical"/>
# <link href="//assets.nobroker.in/static/img/favicon.png" id="favicon" rel="shortcut icon"/>
# <link href="https://images.nobroker.in/static/img/fav64.png" rel="apple-touch-icon"/>
# <meta charset="utf-8"/><meta content="text/html; charset=utf-8" http-equiv="Content-Type"/>
# <meta content="app-id=com.nobroker.app&amp;referrer=utm_source%3Dnobroker%26utm_medium%3DmobileWeb" name="google-play-app"/>
# <meta content="app-id=1200507100, app-argument=nobrokerapp://" name="apple-itunes-app"/>
# <meta content="#fd3752" name="theme-color"/>
# <meta content="flats for sale in Worli Sea Face,   apartments for sale in Worli Sea Face,  houses for sale in Worli Sea Face" name="keywords">
# <meta content="Flats, Apartments for Sale in Worli Sea Face, Mumbai |  Flats in Worli Sea Face  - NoBroker" property="og:title">
# ...

# %%
name=soup.find_all("h2",class_="heading-6 font-semi-bold nb__1AShY")

# %%
name
# Out:
# [<h2 class="heading-6 font-semi-bold nb__1AShY"><span itemprop="name">1 BHK In Independent House  For Sale  In Worli Sea Face, Worli</span> <svg aria-hidden="true" class="jss1" focusable="false" role="presentation" viewbox="0 0 24 24"><path d="M0 0h24v24H0z" fill="none"></path><path d="M19 19H5V5h7V3H5c-1.11 0-2 .9-2 2v14c0 1.1.89 2 2 2h14c1.1 0 2-.9 2-2v-7h-2v7zM14 3v2h3.59l-9.83 9.83 1.41 1.41L19 6.41V10h2V3h-7z"></path></svg></h2>,
#  <h2 class="heading-6 font-semi-bold nb__1AShY"><span itemprop="name">2 BHK In Independent House  For Sale  In Worli </span> <svg aria-hidden="true" class="jss1" focusable="false" role="presentation" viewbox="0 0 24 24"><path d="M0 0h24v24H0z" fill="none"></path><path d="M19 19H5V5h7V3H5c-1.11 0-2 .9-2 2v14c0 1.1.89 2 2 2h14c1.1 0 2-.9 2-2v-7h-2v7zM14 3v2h3.59l-9.83 9.83 1.41 1.41L19 6.41V10h2V3h-7z"></path></svg></h2>,
# ...

# %%
name[0].text
# Out:
# '1 BHK In Independent House  For Sale  In Worli Sea Face, Worli '

# %%
name[1].text
# Out:
# '2 BHK In Independent House  For Sale  In Worli  '

# %%
name[2].text
# Out:
# '2 BHK Apartment  For Sale  In Himalaya In Worli '

# %%
property_name=[]

# %%
for i in name:
    x=i.text
    property_name.append(x)

# %%
property_name
# Out:
# ['1 BHK In Independent House  For Sale  In Worli Sea Face, Worli ',
#  '2 BHK In Independent House  For Sale  In Worli  ',
#  '2 BHK Apartment  For Sale  In Himalaya In Worli ',
#  '2 BHK Flat  For Sale  In Alpa Apartments In Worli ',
#  '3 BHK Flat  For Sale  In Alpa Apartments In Worli ',
#  '1 RK Flat  For Sale  In Dhakal Patil House In Worli Koliwada Vailankanni Cross ',
#  '2 BHK Apartment  For Sale  In Himalaya In Worli ',
#  '1 BHK Flat  For Sale  In Kashai Bai Cottage  In Worli ',
#  '1 RK In Independent House  For Sale  In Shree Ram Lane ']

# %%
pricep=soup.find_all("div",class_="nb__2NPHR")

# %%
pricep
# Out:
# [<div class="nb__2NPHR nb__1imT-"><meta content="Title verification and loan availability" itemprop="name"/><span class="nb__2di3N"><span class="nb__3cC_v nb__2fCmT">Not under loan</span><span class="nb__2w-FV nb__1nquT"><span>₹</span> </span></span></div>,
#  <div class="nb__2NPHR" itemprop="additionalProperty" itemscope="" itemtype="http://schema.org/PropertyValue"><div class="font-semi-bold heading-6" id="minRent" itemprop="valueReference" itemscope="" itemtype="http://schema.org/PropertyValue"><meta content="Minimum Rent" itemprop="name"/><meta content="INR" itemprop="unitCode"/><div class="nb__3oNyC">650 sqft</div></div><div class="heading-7">Builtup</div></div>,
#  <div class="nb__2NPHR"><meta content="RoomTypes Available" itemprop="name"/><div class="font-semi-bold heading-6" id="roomType"><span>₹</span>57,314/Month</div><div class="heading-7">Estimated EMI</div></div>,
# ...

# %%
pricep[0].text
# Out:
# 'Not under loan₹ '

# %%
pricep[1].text
# Out:
# '650 sqftBuiltup'

# %%
pricep[2].text
# Out:
# '₹57,314/MonthEstimated EMI'

# %%
pricep[3].text
# Out:
# '₹1 Crore₹15,385 per sq.ft.'

# %%
pricep[4].text
# Out:
# 'Not under loan₹ '

# %%
pricep[5].text
# Out:
# '750 sqftBuiltup'

# %%
pricep[6].text
# Out:
# '₹63,045/MonthEstimated EMI'

# %%
pricep[7].text
# Out:
# '₹1.1 Crores₹14,667 per sq.ft.'

# %%
pricep[8].text
# Out:
# 'Not under loan₹ '

# %%
property_price=pricep[3::4]

# %%
property_price[0].text
# Out:
# '₹1 Crore₹15,385 per sq.ft.'

# %%
price_of_property=[]
for i in property_price:
    x=i.text
    price_of_property.append(x)

# %%
price_of_property
# Out:
# ['₹1 Crore₹15,385 per sq.ft.',
#  '₹1.1 Crores₹14,667 per sq.ft.',
#  '₹4 Crores₹50,891 per sq.ft.',
#  '₹7.47 Crores₹67,000 per sq.ft.',
#  '₹7.47 Crores₹67,000 per sq.ft.',
#  '₹25 Lacs₹14,706 per sq.ft.',
#  '₹2.75 Crores₹47,826 per sq.ft.',
#  '₹45 Lacs₹15,000 per sq.ft.',
#  '₹35 Lacs₹23,333 per sq.ft.']

# %%
emi=[]

# %%
emihome=pricep[2::4]

# %%
for i in emihome:
    x=i.text
    emi.append(x)

# %%
emi
# Out:
# ['₹57,314/MonthEstimated EMI',
#  '₹63,045/MonthEstimated EMI',
#  '₹2.29 Lacs/MonthEstimated EMI',
#  '₹4.28 Lacs/MonthEstimated EMI',
#  '₹4.28 Lacs/MonthEstimated EMI',
#  '₹14,328/MonthEstimated EMI',
#  '₹1.58 Lacs/MonthEstimated EMI',
#  '₹25,791/MonthEstimated EMI',
#  '₹20,060/MonthEstimated EMI']

# %%
address=soup.find_all("div",class_="nb__2CMjv")

# %%
address
# Out:
# [<div class="nb__2CMjv">Independent House, FG Men dosa house 140 D Worli Village</div>,
#  <div class="nb__2CMjv">Independent House, VB Worlikar Marg, near shivsena shakha,</div>,
#  <div class="nb__2CMjv"><a class="nb__17tcx" href="/himalaya-worli_mumbai-prjt-5bac1ede714b564981dcdd92" target="_blank">Himalaya</a>  <!-- -->Himalaya Apt, Sea Face Road, Worli, Mumbai - 400018, India</div>,
#  <div class="nb__2CMjv">Municipal Colony near Hotel Hiltop</div>,
#  <div class="nb__2CMjv">Municipal Colony near Hotel Hiltop</div>,
#  <div class="nb__2CMjv">worli koliwada sai mandir</div>,
#  <div class="nb__2CMjv"><a class="nb__17tcx" href="/himalaya-worli_mumbai-prjt-5bac1ede714b564981dcdd92" target="_blank">Himalaya</a>  <!-- -->Himalaya Apt, Sea Face Road, Worli, Mumbai - 400018, India</div>,
#  <div class="nb__2CMjv">Koliwada, Near Hanuman Temple</div>,
#  <div class="nb__2CMjv">Independent House, Shri Ram Lane</div>]

# %%
address[0].text
# Out:
# 'Independent House, FG Men dosa house 140 D Worli Village'

# %%
locality=[]

# %%
for i in address:
    x=i.text
    locality.append(x)

# %%
locality
# Out:
# ['Independent House, FG Men dosa house 140 D Worli Village',
#  'Independent House, VB Worlikar Marg, near shivsena shakha,',
#  'Himalaya\xa0 Himalaya Apt, Sea Face Road, Worli, Mumbai - 400018, India',
#  'Municipal Colony near Hotel Hiltop',
#  'Municipal Colony near Hotel Hiltop',
#  'worli koliwada sai mandir',
#  'Himalaya\xa0 Himalaya Apt, Sea Face Road, Worli, Mumbai - 400018, India',
#  'Koliwada, Near Hanuman Temple',
#  'Independent House, Shri Ram Lane']

# %%
df_property=pd.DataFrame({"Property Name":property_name,"Price":price_of_property,"EMI":emi,"Location":locality})

# %%
df_property
# Out:
#                                        Property Name  \
# 0  1 BHK In Independent House  For Sale  In Worli...
# 1   2 BHK In Independent House  For Sale  In Worli
# 2   2 BHK Apartment  For Sale  In Himalaya In Worli
# 3  2 BHK Flat  For Sale  In Alpa Apartments In Wo...
# 4  3 BHK Flat  For Sale  In Alpa Apartments In Wo...
# 5  1 RK Flat  For Sale  In Dhakal Patil House In ...
# 6   2 BHK Apartment  For Sale  In Himalaya In Worli
# 7  1 BHK Flat  For Sale  In Kashai Bai Cottage  I...
# 8  1 RK In Independent House  For Sale  In Shree ...
#
#                             Price                            EMI  \
# 0      ₹1 Crore₹15,385 per sq.ft.     ₹57,314/MonthEstimated EMI
# 1   ₹1.1 Crores₹14,667 per sq.ft.     ₹63,045/MonthEstimated EMI
# 2     ₹4 Crores₹50,891 per sq.ft.  ₹2.29 Lacs/MonthEstimated EMI
# 3  ₹7.47 Crores₹67,000 per sq.ft.  ₹4.28 Lacs/MonthEstimated EMI
# 4  ₹7.47 Crores₹67,000 per sq.ft.  ₹4.28 Lacs/MonthEstimated EMI
# ...
