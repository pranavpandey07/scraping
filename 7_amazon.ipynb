# %%
import pandas as pd
import requests
from bs4 import BeautifulSoup
import numpy as np
import re

# %%
url="https://www.amazon.in/s?k=mobile+phone+under+20000&ref=nb_sb_noss_2"
output=requests.get(url)

# %%
output
# Out:
# <Response [503]>

# %%
soup=BeautifulSoup(output.content,"html.parser")

# %%
headers = ({'User-Agent':
            'Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/44.0.2403.157 Safari/537.36',
            'Accept-Language': 'en-US, en;q=0.5'})

# %%
output=requests.get(url,headers=headers)

# %%
soup=BeautifulSoup(output.content,"html.parser")

# %%
print(soup)
# Out:
# <!DOCTYPE html>
# <html class="a-no-js" data-19ax5a9jf="dingo" lang="en-in"><!-- sp:feature:head-start -->
# <head><script>var aPageStart = (new Date()).getTime();</script><meta charset="utf-8"/>
# <script type="text/javascript">var ue_t0=ue_t0||+new Date();</script>
# <!-- sp:feature:cs-optimization -->
# <meta content="on" http-equiv="x-dns-prefetch-control"/>
# <link href="https://images-eu.ssl-images-amazon.com" rel="dns-prefetch"/>
# <link href="https://m.media-amazon.com" rel="dns-prefetch"/>
# <link href="https://completion.amazon.com" rel="dns-prefetch"/>
# <script type="text/javascript">
# window.ue_ihb = (window.ue_ihb || window.ueinit || 0) + 1;
# if (window.ue_ihb === 1) {
#
# var ue_csm = window,
#     ue_hob = +new Date();
# ...

# %%
mobile_name=soup.find_all("span",class_="a-size-medium a-color-base a-text-normal")

# %%
mobile_name
# Out:
# [<span class="a-size-medium a-color-base a-text-normal">Oppo F19 (Prism Black, 6GB RAM, 128GB Storage) - 6.43" Inch AMOLED Punch-Hole Display | in-Display Fingerprint 3.0 | 5000 mAh Battery | 33W Flash Charging</span>,
#  <span class="a-size-medium a-color-base a-text-normal">Redmi 9 (Sky Blue, 4GB RAM, 64GB Storage) | 2.3GHz Mediatek Helio G35 Octa core Processor</span>,
#  <span class="a-size-medium a-color-base a-text-normal">Redmi 9A (Nature Green, 2GB RAM, 32GB Storage) | 2GHz Octa-core Helio G25 Processor | 5000 mAh Battery</span>,
#  <span class="a-size-medium a-color-base a-text-normal">Oppo A31 (Fantasy White, 6GB RAM, 128GB Storage) with No Cost EMI/Additional Exchange Offers</span>,
#  <span class="a-size-medium a-color-base a-text-normal">Tecno Spark 7T(Jewel Blue, 4GB RAM, 64GB Storage) 6000 mAh Battery| 48 MP AI Dual Rear Camera, 6.52 Handy Size</span>,
# ...

# %%
mobile_name[0].text.split(",")[0].replace("(","")
# Out:
# 'Oppo F19 Prism Black'

# %%
name=[]

# %%
for i in mobile_name:
    x=i.text.split(",")[0].replace("(","")
    name.append(x)

# %%
name
# Out:
# ['Oppo F19 Prism Black',
#  'Redmi 9 Sky Blue',
#  'Redmi 9A Nature Green',
#  'Oppo A31 Fantasy White',
#  'Tecno Spark 7TJewel Blue',
#  'Samsung Galaxy M11 Black',
#  'Samsung Galaxy M12 Blue',
#  'Samsung Galaxy M31 Ocean Blue',
#  'Oppo A31 Mystery Black',
#  'Redmi 9 Carbon Black',
#  'Redmi 9AMidnight Black 3GB RAM 32GB Storage) | 2GHz Octa-core Helio G25 Processor | 5000 mAh Battery',
#  'realme C11 2021) Cool Blue',
#  'Redmi Note 9 Pebble Grey',
#  'Redmi 9A Sea Blue 3GB RAM 32GB Storage)| 2GHz Octa-core Helio G25 Processor | 5000 mAh Battery',
#  'Redmi Note 10 Aqua Green',
#  'Redmi 9A Midnight Black 2GB RAM 32GB Storage) | 2GHz Octa-core Helio G25 Processor | 5000 mAh Battery',
#  'Redmi 9A Sea Blue 2GB RAM 32GB Storage) | 2GHz Octa-core Helio G25 Processor | 5000 mAh Battery']

# %%
price=soup.find_all("span",class_="a-price")

# %%
price
# Out:
# [<span class="a-price" data-a-color="price" data-a-size="l"><span class="a-offscreen">₹18,990</span><span aria-hidden="true"><span class="a-price-symbol">₹</span><span class="a-price-whole">18,990</span></span></span>,
#  <span class="a-price a-text-price" data-a-color="secondary" data-a-size="b" data-a-strike="true"><span class="a-offscreen">₹20,990</span><span aria-hidden="true">₹20,990</span></span>,
#  <span class="a-price" data-a-color="price" data-a-size="l"><span class="a-offscreen">₹8,999</span><span aria-hidden="true"><span class="a-price-symbol">₹</span><span class="a-price-whole">8,999</span></span></span>,
#  <span class="a-price a-text-price" data-a-color="secondary" data-a-size="b" data-a-strike="true"><span class="a-offscreen">₹10,999</span><span aria-hidden="true">₹10,999</span></span>,
# ...

# %%
price[0].text.split("\u20B9")[1]
# Out:
# '18,990'

# %%
mobile_price=[]
for i in price:
    x=i.text.split("\u20B9")[1]
    mobile_price.append(x)

# %%
mobile_price
# Out:
# ['18,990',
#  '20,990',
#  '8,999',
#  '10,999',
#  '6,999',
#  '8,499',
#  '12,490',
#  '15,990',
#  '8,999',
#  '10,999',
#  '9,999',
#  '14,999',
#  '12,490',
#  '15,990',
#  '8,999',
#  '10,999',
#  '7,799',
#  '9,499',
#  '6,999',
#  '7,999',
#  '11,499',
#  '14,999',
#  '7,799',
#  '9,499',
#  '12,999',
#  '15,999',
#  '6,999',
#  '8,499',
#  '6,999',
#  '8,499']

# %%
links = soup.find('div').find_all( src=True)

# %%
k=links[0]

# %%
k
# Out:
# <img alt="" height="1" onload="window.ue_sbl &amp;&amp; window.ue_sbl();" src="//fls-eu.amazon.in/1/batch/1/OP/A21TJRUUN4KGV:260-7273629-9622569:TQ2N427APM89AHT263BW$uedata=s:%2Frd%2Fuedata%3Fstaticb%26id%3DTQ2N427APM89AHT263BW:0" style="display:none;visibility:hidden;" width="1"/>

# %%
images=[]
for item in links:
    x=(item['src'])
    images.append(x)

# %%
images
# Out:
# ['//fls-eu.amazon.in/1/batch/1/OP/A21TJRUUN4KGV:260-7273629-9622569:TQ2N427APM89AHT263BW$uedata=s:%2Frd%2Fuedata%3Fstaticb%26id%3DTQ2N427APM89AHT263BW:0',
#  'https://images-eu.ssl-images-amazon.com/images/G/31/gno/sprites/nav-sprite-global-1x-hm-dsk-reorg._CB405936311_.png',
#  'https://images-eu.ssl-images-amazon.com/images/G/31/IN-hq/2021/img/Mobile_Traffic_/XCM_Manual_1321458_1651511_IN_3781247_400x39_en_IN._CB655944656_.jpg',
#  'https://m.media-amazon.com/images/I/71crCF+ogwL._AC_UY218_.jpg',
#  'https://m.media-amazon.com/images/I/71A9Vo1BatL._AC_UY218_.jpg',
#  'https://m.media-amazon.com/images/I/71sxlhYhKWL._AC_UY218_.jpg',
#  'https://m.media-amazon.com/images/I/61CnyJ-IbML._AC_UY218_.jpg',
#  'https://m.media-amazon.com/images/I/81aWyRY67SS._AC_UY218_.jpg',
#  'https://m.media-amazon.com/images/I/710jkZNub3S._AC_UY218_.jpg',
#  'https://m.media-amazon.com/images/I/71yYaNztZ0L._AC_UY218_.jpg',
#  'https://m.media-amazon.com/images/I/71-Su4Wr0HL._AC_UY218_.jpg',
# ...

# %%
avg_rating=soup.find_all("span",class_="a-size-base")

# %%
avg_rating[0].text
# Out:
# '713'

# %%
rating=[]
for i in avg_rating:
    x=i.text.replace("\n","")
    rating.append(x)

# %%
rating
# Out:
# ['713',
#  '67,356',
#  '69,941',
#  '22,814',
#  '1,387',
#  '4,115',
#  '35,092',
#  '223,037',
#  '22,814',
#  '67,356',
#  '69,941',
#  '376',
#  '89,019',
#  '69,941',
#  '72,980',
#  '69,941',
#  '69,941',
#  'mobile phone under 20000-30000',
#  'mobile phone',
#  'mobile phone under 20000-25000',
#  'mobile phone under 30000',
#  'mobile phone under 10000-15000',
#  'iphone',
#  ' or ',
#  'Delivery Day',
#  'Get It Today',
#  'Get It by Tomorrow',
#  'Department',
#  'Smartphones & Basic Mobiles',
#  'Smartphones',
#  'Electronics',
#  'Avg. Customer Review',
#  'Brand',
#  'Oppo',
#  'Redmi',
#  'Samsung',
#  'Vivo',
#  'realme',
#  'Tecno',
#  'OnePlus',
#  'Micromax',
#  'Panasonic',
#  'Nokia',
#  'Gionee',
#  'Xifo',
#  'LG',
#  'IKALL',
#  'Generic',
#  'Moto',
#  'HUAWEI',
#  'Microsoft',
#  'Price',
#  'Under ₹1,000',
#  '₹1,000 - ₹5,000',
#  '₹5,000 - ₹10,000',
#  '₹10,000 - ₹20,000',
#  'Deals',
#  "Today's Deals",
#  'RAM',
#  '8 GB & above',
#  '6 GB',
#  '4 GB',
# ...

# %%
rate=rating[0:17]

# %%
rate
# Out:
# ['713',
#  '67,356',
#  '69,941',
#  '22,814',
#  '1,387',
#  '4,115',
#  '35,092',
#  '223,037',
#  '22,814',
#  '67,356',
#  '69,941',
#  '376',
#  '89,019',
#  '69,941',
#  '72,980',
#  '69,941',
#  '69,941']

# %%
len(rate)
# Out:
# 17

# %%
img=images[0:17]

# %%
len(img)
# Out:
# 17

# %%
price=mobile_price[0:17]

# %%
len(price)
# Out:
# 17

# %%
naam=name[0:17]

# %%
len(naam)
# Out:
# 17

# %%
df_mobile=pd.DataFrame({"Name of Phone":naam,"Mobile Price":price,"Image":img,"Average ratings":rate})

# %%
df_mobile
# Out:
#                                         Name of Phone Mobile Price  \
# 0                                Oppo F19 Prism Black       18,990
# 1                                    Redmi 9 Sky Blue       20,990
# 2                               Redmi 9A Nature Green        8,999
# 3                              Oppo A31 Fantasy White       10,999
# 4                            Tecno Spark 7TJewel Blue        6,999
# 5                            Samsung Galaxy M11 Black        8,499
# 6                             Samsung Galaxy M12 Blue       12,490
# 7                       Samsung Galaxy M31 Ocean Blue       15,990
# 8                              Oppo A31 Mystery Black        8,999
# 9                                Redmi 9 Carbon Black       10,999
# 10  Redmi 9AMidnight Black 3GB RAM 32GB Storage) |...        9,999
# 11                         realme C11 2021) Cool Blue       14,999
# 12                           Redmi Note 9 Pebble Grey       12,490
# ...
